# %%
import pandas as pd
import seaborn as sns
import numpy as np
import sklearn

# %%
data=pd.read_csv("C:/Users/Shubham/Documents/power BI/data sets/cradit_card_dataset1.csv")

# %%
data.head()
# Out:
#    step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0     0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1     0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2     0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3     0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4     0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
#
#               category  amount  fraud
# 0  'es_transportation'    4.55      0
# 1  'es_transportation'   39.68      0
# 2  'es_transportation'   26.89      0
# 3  'es_transportation'   17.25      0
# 4  'es_transportation'   35.72      0

# %%
data.tail()
# Out:
#         step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 594638   179  'C1753498738'  '3'    'F'    '28007'  'M1823072687'     '28007'
# 594639   179   'C650108285'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 594640   179   'C123623130'  '2'    'F'    '28007'   'M349281107'     '28007'
# 594641   179  'C1499363341'  '5'    'M'    '28007'  'M1823072687'     '28007'
# 594642   179   'C616528518'  '4'    'F'    '28007'  'M1823072687'     '28007'
#
#                    category  amount  fraud
# 594638  'es_transportation'   20.53      0
# 594639  'es_transportation'   50.73      0
# 594640         'es_fashion'   22.44      0
# 594641  'es_transportation'   14.46      0
# 594642  'es_transportation'   26.93      0

# %%
unfilled=data.loc[data['fraud']==1]
filled = data.loc[data['fraud']==0]

# %%
unfilled.sum()
# Out:
# step                                                      644400
# customer       'C583110837''C1332295774''C1160421902''C966214...
# age            '3''3''3''3''4''2''2''5''4''3''3''1''2''2''5''...
# gender         'M''M''M''M''F''F''F''F''F''F''M''F''F''F''F''...
# zipcodeOri     '28007''28007''28007''28007''28007''28007''280...
# merchant       'M480139044''M480139044''M857378720''M85737872...
# zipMerchant    '28007''28007''28007''28007''28007''28007''280...
# category       'es_health''es_health''es_hotelservices''es_ho...
# amount                                                3822671.17
# fraud                                                       7200
# dtype: object

# %%
unfilled.count()
# Out:
# step           7200
# customer       7200
# age            7200
# gender         7200
# zipcodeOri     7200
# merchant       7200
# zipMerchant    7200
# category       7200
# amount         7200
# fraud          7200
# dtype: int64

# %%
filled.count()
# Out:
# step           587443
# customer       587443
# age            587443
# gender         587443
# zipcodeOri     587443
# merchant       587443
# zipMerchant    587443
# category       587443
# amount         587443
# fraud          587443
# dtype: int64

# %%
len(unfilled)
# Out:
# 7200

# %%
len(filled)
# Out:
# 587443

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
x=data.iloc[:,:-1]
y=data['fraud']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.35)

# %%
clf = linear_model.LogisticRegression(C=1)

# %%
clf.fit(x_train, y_train)

# %%
y_pred =np.array(clf.predict(x_test))
y=np.array(y_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
print(confusion_matrix(y_test,y_pred))

# %%
print(accuracy_score(y_test,y_pred))

# %%
print(classification_report(y_test,y_pred))

# %%
sns.relplot(x= 'amount' , y='step',hue='fraud' , data=data)
